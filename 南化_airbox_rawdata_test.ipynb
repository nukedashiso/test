# %%
import requests

# %%
import pandas as pd
import json

# %%
r19 = requests.get("https://pm25.lass-net.org/data/history-date.php?device_id=74DA38F208DC&date=2020-05-05", verify=False)
r20 = requests.get("https://pm25.lass-net.org/data/history-date.php?device_id=74DA38F208DC&date=2020-05-06", verify=False)
#r21 = requests.get("https://pm25.lass-net.org/data/history-date.php?device_id=08BEAC0A0746&date=2020-04-21", verify=False)
#r22 = requests.get("https://pm25.lass-net.org/data/history-date.php?device_id=08BEAC0A0746&date=2020-04-22", verify=False)
#r23 = requests.get("https://pm25.lass-net.org/data/history-date.php?device_id=08BEAC0A0746&date=2020-04-23", verify=False)
#r24 = requests.get("https://pm25.lass-net.org/data/history-date.php?device_id=08BEAC0A0746&date=2020-04-24", verify=False)

# 輸入airbox api網址

print(r19.status_code)
#print(r20.status_code)
#print(r21.status_code)
#print(r22.status_code)
#print(r23.status_code)
#print(r24.status_code)

#測試看有沒有讀取成功：
#向網路伺服器發出請求時都會回傳 HTTP 狀態碼，表示有關請求的情況，常見的有：
#200 一切順利，結果已經回傳
#301 伺服器將使用者重新定向（re-direct）到另一個位址，當網站更換網域名稱或更改 Routes 時可能會發生
#400 錯誤的請求
#401 未通過伺服器的身份驗證，當請求沒有一併發送正確憑證時會發生。
#403 伺服器已經理解請求，但是拒絕執行它，意即與請求一併發送的憑證無效
#404 請求失敗
# Out:
# D:\anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# 200

# %%
list_of_dicts_19 = r19.json()
list_of_dicts_20 = r20.json()
#list_of_dicts_21 = r21.json()
#list_of_dicts_22 = r22.json()
#list_of_dicts_23 = r23.json()
#list_of_dicts_24 = r24.json()

#將json檔編碼儲存成dict

# %%
def get_target_value(key, dic, tmp_list):
    """
    :param key: 目标key值
    :param dic: JSON数据
    :param tmp_list: 用于存储获取的数据
    :return: list
    """
    if not isinstance(dic, dict) or not isinstance(tmp_list, list):  # 对传入数据进行格式校验
        return 'argv[1] not an dict or argv[-1] not an list '

    if key in dic.keys():
        tmp_list.append(dic[key])  # 传入数据存在则存入tmp_list

    for value in dic.values():  # 传入数据不符合则对其value值进行遍历
        if isinstance(value, dict):
            get_target_value(key, value, tmp_list)  # 传入数据的value值是字典，则直接调用自身
        elif isinstance(value, (list, tuple)):
            _get_value(key, value, tmp_list)  # 传入数据的value值是列表或者元组，则调用_get_value


    return tmp_list


def _get_value(key, val, tmp_list):
    for val_ in val:
        if isinstance(val_, dict):  
            get_target_value(key, val_, tmp_list)  # 传入数据的value值是字典，则调用get_target_value
        elif isinstance(val_, (list, tuple)):
            _get_value(key, val_, tmp_list)   # 传入数据的value值是列表或者元组，则调用自身
            
            
#主要核心code，多層dict擷取資料，直接套用即可
#參考路徑：https://www.cnblogs.com/Detector/p/8085460.html

# %%
pm10_0419 = get_target_value('s_d1', list_of_dicts_19, [])
pm10_0420 = get_target_value('s_d1', list_of_dicts_20, [])
#pm25_0421 = get_target_value('s_d0', list_of_dicts_21, [])
#pm25_0422 = get_target_value('s_d0', list_of_dicts_22, [])
#pm25_0423 = get_target_value('s_d0', list_of_dicts_23, [])
#pm25_0424 = get_target_value('s_d0', list_of_dicts_24, [])

#擷取s_d0內容

# %%
temp_0419 = get_target_value('s_t0',list_of_dicts_19, [])
temp_0420 = get_target_value('s_t0',list_of_dicts_20, [])
#temp_0421 = get_target_value('s_t0',list_of_dicts_21, [])
#temp_0422 = get_target_value('s_t0',list_of_dicts_22, [])
#temp_0423 = get_target_value('s_t0',list_of_dicts_23, [])
#temp_0424 = get_target_value('s_t0',list_of_dicts_24, [])

#擷取s_t0內容

# %%
hum_0419 = get_target_value('s_h0', list_of_dicts_19, [])
hum_0420 = get_target_value('s_h0', list_of_dicts_20, [])
#hum_0421 = get_target_value('s_h0', list_of_dicts_21, [])
#hum_0422 = get_target_value('s_h0', list_of_dicts_22, [])
#hum_0423 = get_target_value('s_h0', list_of_dicts_23, [])
#hum_0424 = get_target_value('s_h0', list_of_dicts_24, [])

#擷取s_h0內容

# %%
date_0419 = get_target_value('date', list_of_dicts_19, [])
date_0420 = get_target_value('date', list_of_dicts_20, [])
#date_0421 = get_target_value('date', list_of_dicts_21, [])
#date_0422 = get_target_value('date', list_of_dicts_22, [])
#date_0423 = get_target_value('date', list_of_dicts_23, [])
#date_0424 = get_target_value('date', list_of_dicts_24, [])

#擷取date內容

# %%
time_0419 = get_target_value('time', list_of_dicts_19, [])
time_0420 = get_target_value('time', list_of_dicts_20, [])
#time_0421 = get_target_value('time', list_of_dicts_21, [])
#time_0422 = get_target_value('time', list_of_dicts_22, [])
#time_0423 = get_target_value('time', list_of_dicts_23, [])
#time_0424 = get_target_value('time', list_of_dicts_24, [])

#擷取time內容

# %%
site_0419 = get_target_value('SiteName', list_of_dicts_19, [])
site_0420 = get_target_value('SiteName', list_of_dicts_20, [])
#site_0421 = get_target_value('SiteName', list_of_dicts_21, [])
#site_0422 = get_target_value('SiteName', list_of_dicts_22, [])
#site_0423 = get_target_value('SiteName', list_of_dicts_23, [])
#site_0424 = get_target_value('SiteName', list_of_dicts_24, [])

#擷取SiteName內容

# %%
site_0419
# Out:
# ['台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
#  '台東縣縣立賓茂國小',
# ...

# %%
df19 = pd.DataFrame(site_0419, date_0419)
#df20 = pd.DataFrame(site_0420, date_0420)
#df21 = pd.DataFrame(site_0421, date_0421)
#df22 = pd.DataFrame(site_0422, date_0422)
#df23 = pd.DataFrame(site_0423, date_0423)
#df24 = pd.DataFrame(site_0424, date_0424)

#將兩項list合成df，試過三項一起合不行

# %%
df19['Time'] = time_0419
#df20['Time'] = time_0420
#df21['Time'] = time_0421
#df22['Time'] = time_0422
#df23['Time'] = time_0423
#df24['Time'] = time_0424

#增加"Time"欄位

# %%
df19['PM10'] = pm10_0419
#df20['PM2.5'] = pm25_0420
#df21['PM2.5'] = pm25_0421
#df22['PM2.5'] = pm25_0422
#df23['PM2.5'] = pm25_0423
#df24['PM2.5'] = pm25_0424

#增加"PM2.5"欄位

# %%
#df['Temperature'] = temp_0420
#df['Humidity'] = hum_0420
#df['PM2.5'] = pm25_0420

# %%
writer=pd.ExcelWriter('airbox_賓茂國小.xlsx')
df19.to_excel(writer, sheet_name = '109505')
#df20.to_excel(writer, sheet_name = '1090420')
#df21.to_excel(writer, sheet_name = '1090421')
#df22.to_excel(writer, sheet_name = '1090422')
#df23.to_excel(writer, sheet_name = '1090423')
#df24.to_excel(writer, sheet_name = '1090424')

writer.save()

#將各別df存進同一excel中之不同sheet
